# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np

# %%
# Passo 2: Dados simulados com mais amostras e leve ruído
np.random.seed(42)     # Para reprodutividade 
X = np.arange(1, 101).reshape(-1, 1)     # X de 1 à 10
Y = 2 * X.flatten() + np.random.normal(0, 1, size=X.shape[0])    # Y = 2x + ruído

# %%
# Criando o gráfico de dispersão
plt.figure(figsize=(10, 7))
plt.scatter(X, Y, color='blue', label='Dados simulados (com ruído)')
plt.plot(X, 2 * X.flatten(), color='red', linestyle='--', label='Relação ideal (Y = 2x)')

# Configurações do gráfico
plt.title('Gráfico de Dispersão: X vs Y')
plt.xlabel('X (variável independente)')
plt.ylabel('y (variável dependente)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print("Dados de entrada (X):")
print(X[0:5])
print("\nDados de saída (Y):")
print(Y[0:5])
print()
# Out:
# Dados de entrada (X):
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]
#
# Dados de saída (Y):
# [2.49671415 3.8617357  6.64768854 9.52302986 9.76584663]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print("X_treino:", X_train.flatten())
print("Y_treino:", Y_train)
print("X_teste:", X_test.flatten())
print("Y_teste:", Y_test)
print()
# Out:
# X_treino: [ 56  89  27  43  70  16  41  97  10  73  12  48  86  29  94   6  67  66
#   36  17  50  35   8  96  28  20  82  26  63  14  25   4  18  39   9  79
#    7  65  37  90  57 100  55  44  51  68  47  69  62  98  80  42  59  49
#   99  58  76  33  95  60  64  85  38  30   2  53  22   3  24  88  92  75
#   87  83  21  61  72  15  93  52]
# Y_treino: [112.93128012 177.4702398   52.84900642  85.88435172 139.35488025
#   31.43771247  82.73846658 194.29612028  20.54256004 145.96417396
#   23.53427025  97.05712223 171.49824296  57.39936131 187.67233785
#   11.76586304 133.92798988 133.35624003  70.77915635  32.98716888
#   98.23695984  70.82254491  16.76743473 190.53648505  56.37569802
#   38.5876963  164.35711257  52.11092259 124.89366503  26.08671976
#   49.45561728   9.52302986  36.31424733  76.67181395  17.53052561
#  158.09176078  15.57921282 130.81252582  74.2088636  180.51326743
#  113.16078248 199.76541287 111.03099952  87.6988963  102.32408397
#  137.0035329   93.53936123 138.36163603 123.81434102 196.26105527
#  158.01243109  84.17136828 118.33126343  98.34361829 198.00511346
#  115.69078762 152.8219025   65.98650278 189.60789185 120.97554513
#  126.80379338 169.1915064   74.04032988  59.70830625   3.8617357
#  105.323078    43.7742237    6.64768854  46.57525181 176.32875111
#  184.96864499 147.3802549  174.91540212 167.47789404  43.46564877
#  121.52082576 145.53803657  28.27508217 185.29794691 103.61491772]
# X_teste: [84 54 71 46 45 40 23 81 11  1 19 31 74 34 91  5 77 78 13 32]
# Y_teste: [167.48172978 108.61167629 142.36139561  91.28015579  88.52147801
#   80.19686124  46.0675282  161.78032811  21.53658231   2.49671415
#   37.09197592  61.39829339 149.56464366  66.94228907 182.09707755
#    9.76584663 154.08704707 155.70099265  26.24196227  65.85227818]

# %%
# Passo 4: Criando e treinando o modelo de regressão linear
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Mostrando os coeficientes da reta ajustada: Y = a*x + b
print("Coeficiente angular (a):", model.coef_[0])
print("Intercepto (b):         ", model.intercept_)
print()
# Out:
# Coeficiente angular (a): 2.001220609690667
# Intercepto (b):          -0.1814353967072435

# %%
# Passo 5: Fazendo previsões com o modelo
Y_pred = model.predict(X_test)

# %%
# Comparando valores reais com previsões
print("Valores reais:   ", Y_test)
print("Valores previstos:", np.round(Y_pred, 2))
print()
# Out:
# Valores reais:    [167.48172978 108.61167629 142.36139561  91.28015579  88.52147801
#   80.19686124  46.0675282  161.78032811  21.53658231   2.49671415
#   37.09197592  61.39829339 149.56464366  66.94228907 182.09707755
#    9.76584663 154.08704707 155.70099265  26.24196227  65.85227818]
# Valores previstos: [167.92 107.88 141.91  91.87  89.87  79.87  45.85 161.92  21.83   1.82
#   37.84  61.86 147.91  67.86 181.93   9.82 153.91 155.91  25.83  63.86]

# %%
# Passo 6: Avaliação do modelo - Erro Médio Quadrático(MSE)
mse = mean_squared_error(Y_test, Y_pred)
print("Erro Médio Quadrático (MSE):", round(mse, 4))
print()
# Out:
# Erro Médio Quadrático (MSE): 0.622

# %%
# Passo 7: Visualizando os resultados com gráficos
plt.figure(figsize=(13, 6))

# Gráfico 1: Dados de treino e linha da regressão
plt.subplot(1, 2, 1)
plt.scatter(X_train, Y_train, color='blue', label='Dados de Treino')
plt.plot(X_train, model.predict(X_train), color='red', label='Modelo Treinado')
plt.title('Modelo Treinado vs Dados de Treino')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

# Gráfico 2: Comparando previsões com valores reais no conjunto de teste
plt.subplot(1, 2, 2)
plt.scatter(X_test, Y_test, color='green', label='Real')
plt.scatter(X_test, Y_pred, color='orange', marker='x', s=100, label='Previsto')
plt.plot(X_test, Y_pred, color='orange', linestyle='--')
plt.title('Previsões vs Valores Reais (Teste)')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Passo 2: Dados simulados com mais amostras e leve ruído
np.random.seed(84)     # Para reprodutividade 
X = np.arange(60, 161).reshape(-1, 1)     # X de 1 à 10
Y = 2 * X.flatten() + np.random.normal(0, 1, size=X.shape[0])    # Y = 2x + ruído

# %%
# Criando o gráfico de dispersão
plt.figure(figsize=(10, 7))
plt.scatter(X, Y, color='blue', label='Dados simulados (com ruído)')
plt.plot(X, 2 * X.flatten(), color='red', linestyle='--', label='Relação ideal (Y = 2x)')

# Configurações do gráfico
plt.title('Gráfico de Dispersão: X vs Y')
plt.xlabel('X (variável independente)')
plt.ylabel('y (variável dependente)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print("Dados de entrada (X):")
print(X[0:5])
print("\nDados de saída (Y):")
print(Y[0:5])
print()
# Out:
# Dados de entrada (X):
# [[60]
#  [61]
#  [62]
#  [63]
#  [64]]
#
# Dados de saída (Y):
# [119.8683878  121.53955294 124.66296206 124.67035175 127.45735642]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print("X_treino:", X_train.flatten())
print("Y_treino:", Y_train)
print("X_teste:", X_test.flatten())
print("Y_teste:", Y_test)
print()
# Out:
# X_treino: [149  86 102 130  75 100 132  69 156  71 151 124  88 143  65 107 113  95
#   76 141  94  67 103 133  87  79 154  85 122 109  73  84  63  77  98  68
#  139  66 125  96 148 116 160 114 110 128 106 129 121 158 140 101 118 108
#  150 117 135  92 155 119 123 145  97  89  61 112  81  62  83 147 159 134
#  146 142  80 120 131  74 152 111]
# Y_treino: [300.2441994  170.95009073 204.52454868 260.33055939 149.56953094
#  199.90015438 264.9012512  136.13564006 312.57952184 144.10186254
#  300.56094788 249.72779206 176.44124864 285.99097579 129.26712847
#  213.47169558 225.822057   189.42442669 150.79983452 282.22217046
#  188.16336802 133.77148106 207.13259137 265.78615846 173.41865592
#  158.3819526  306.85481116 168.75270974 244.84010489 216.0307822
#  146.41146356 167.99390261 124.67035175 154.57066863 198.05118127
#  135.95823844 276.59519744 130.96668988 249.50015743 189.39826745
#  294.22616907 232.27355305 319.82445021 227.02427068 220.03299011
#  255.56962887 210.89848768 259.10324126 244.85737157 317.60460002
#  279.36680431 202.18428434 236.21039544 215.21531686 300.18519448
#  235.22535296 269.97285846 182.01836615 310.52875046 236.99913036
#  248.29358776 288.61518695 193.64036636 177.1642434  121.53955294
#  222.3020535  160.77157624 124.66296206 165.68430841 291.90624744
#  319.63208756 267.47399019 292.39428696 284.5049254  158.89752194
#  238.88092204 262.25556888 149.01674881 303.50794602 220.65760355]
# X_teste: [144 115 126 127 105  99  82 104  70  60  78  90 157  93 137  64 153 138
#   72  91 136]
# Y_teste: [286.25857286 229.12402211 250.85478078 252.81505006 210.10496416
#  196.11040019 164.2859114  209.2684037  140.49309921 119.8683878
#  154.32598261 178.99481247 312.33760072 184.91891017 272.51498779
#  127.45735642 305.60911227 277.43478381 142.83196025 182.17523474
#  272.66346773]

# %%
# Passo 4: Criando e treinando o modelo de regressão linear
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Mostrando os coeficientes da reta ajustada: Y = a*x + b
print("Coeficiente angular (a):", model.coef_[0])
print("Intercepto (b):         ", model.intercept_)
print()
# Out:
# Coeficiente angular (a): 2.0056120668632405
# Intercepto (b):          -0.7804518512641607

# %%
# Passo 5: Fazendo previsões com o modelo
Y_pred = model.predict(X_test)

# %%
# Comparando valores reais com previsões
print("Valores reais:   ", Y_test)
print("Valores previstos:", np.round(Y_pred, 2))
print()
# Out:
# Valores reais:    [286.25857286 229.12402211 250.85478078 252.81505006 210.10496416
#  196.11040019 164.2859114  209.2684037  140.49309921 119.8683878
#  154.32598261 178.99481247 312.33760072 184.91891017 272.51498779
#  127.45735642 305.60911227 277.43478381 142.83196025 182.17523474
#  272.66346773]
# Valores previstos: [288.03 229.86 251.93 253.93 209.81 197.78 163.68 207.8  139.61 119.56
#  155.66 179.72 314.1  185.74 273.99 127.58 306.08 275.99 143.62 181.73
#  271.98]

# %%
# Passo 6: Avaliação do modelo - Erro Médio Quadrático(MSE)
mse = mean_squared_error(Y_test, Y_pred)
print("Erro Médio Quadrático (MSE):", round(mse, 4))
print()
# Out:
# Erro Médio Quadrático (MSE): 1.1515

# %%
# Passo 7: Visualizando os resultados com gráficos
plt.figure(figsize=(13, 6))

# Gráfico 1: Dados de treino e linha da regressão
plt.subplot(1, 2, 1)
plt.scatter(X_train, Y_train, color='blue', label='Dados de Treino')
plt.plot(X_train, model.predict(X_train), color='red', label='Modelo Treinado')
plt.title('Modelo Treinado vs Dados de Treino')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

# Gráfico 2: Comparando previsões com valores reais no conjunto de teste
plt.subplot(1, 2, 2)
plt.scatter(X_test, Y_test, color='green', label='Real')
plt.scatter(X_test, Y_pred, color='orange', marker='x', s=100, label='Previsto')
plt.plot(X_test, Y_pred, color='orange', linestyle='--')
plt.title('Previsões vs Valores Reais (Teste)')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

plt.tight_layout()
plt.show()
